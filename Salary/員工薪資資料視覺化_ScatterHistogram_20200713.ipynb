# %% [markdown]
# ## [公開資訊觀測站](https://mops.twse.com.tw/mops/web/t100sb14)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SemiConductor.csv', encoding='cp950')

# %%
df.head()
# Out:
#    產業類別  公司代號 公司名稱 公司類別  公司年度資訊-員工福利費用(仟元)  公司年度資訊-員工薪資費用(仟元)  公司年度資訊-員工人數(人)  \
# 0  半導體業  2302   麗正   一般            47891.0              38366              73
# 1  半導體業  2303   聯電   一般         22354612.0           19970279           14583
# 2  半導體業  2329   華泰   一般          3724873.0            3010873            6388
# 3  半導體業  2330  台積電   一般         96182936.0           86909632           44050
# 4  半導體業  2337   旺宏   一般          5815451.0            5036696            3853
#
#    公司年度資訊-平均員工福利費用(仟元/人)  公司年度資訊-平均員工薪資費用(仟元/人) 公司年度資訊－平均員工薪資費用調整變動情形(%)  \
# 0                    656                    526                   -4.9 %
# 1                   1533                   1369                    1.9 %
# 2                    583                    471                   14.9 %
# 3                   2183                   1973                   -0.9 %
# 4                   1509                   1307                  -12.1 %
#
#    公司年度資訊-每股盈餘(元/股)  同產業公司-平均員工福利費用(仟元/人)  同產業公司-平均員工薪資費用(仟元/人)  \
# 0              0.00                  1593                  1418
# 1              0.82                  1593                  1418
# 2              1.06                  1593                  1418
# 3             13.32                  1593                  1418
# 4              1.64                  1593                  1418
#
#    同產業公司-平均每股盈餘(元/股)  Unnamed: 14
# 0               6.66          NaN
# 1               6.66          NaN
# 2               6.66          NaN
# 3               6.66          NaN
# 4               6.66          NaN

# %%
si = np.array(df.loc[df['公司年度資訊-平均員工薪資費用(仟元/人)']>1000,'公司年度資訊-平均員工薪資費用(仟元/人)'])
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
plt.figure(figsize=(15,10))
plt.scatter(df[df['公司年度資訊-平均員工薪資費用(仟元/人)']>1000].公司名稱,df.loc[df['公司年度資訊-平均員工薪資費用(仟元/人)']>1000,'公司年度資訊-平均員工薪資費用(仟元/人)'],c=np.log2(si),s=0.0001*si**2)
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.title('108年半導體上市公司平均員工薪資費用',fontsize=25)
# Out:
# Text(0.5,1,'108年半導體上市公司平均員工薪資費用')

# %%
np.log10(np.array(df.loc[df['公司年度資訊-平均員工薪資費用(仟元/人)']>3000,'公司年度資訊-平均員工薪資費用(仟元/人)']))
# Out:
# array([4.16384688, 3.80536491, 4.64394591, 3.58579901, 3.56561172,
#        3.50514998, 3.56549363, 3.86587353, 3.93222001, 3.69469293,
#        4.02901833, 3.7649976 ])

# %% [markdown]
# # Histogram (直方圖)：如果要統計連續性的變數(x軸)，可以使用直方圖，它會自動分組距(bins)，它只能針對一個變數作統計。

# %%
plt.figure(figsize=(8,6))
my_bins = 10
arr = plt.hist(df['公司年度資訊-平均員工薪資費用(仟元/人)']/10,bins=my_bins)
for i in range(my_bins):
    plt.text(arr[1][i],arr[0][i],'      '+str(int(arr[0][i])))
plt.ylabel('公司數',fontsize=15)
plt.xlabel('平均員工薪資費用(萬)',fontsize=15)
plt.grid()

# %%
df['公司年度資訊-平均員工薪資費用(仟元/人)'].describe()
# Out:
# count      68.000000
# mean     1236.191176
# std       589.646675
# min       471.000000
# 25%       705.000000
# 50%      1249.000000
# 75%      1597.500000
# max      2921.000000
# Name: 公司年度資訊-平均員工薪資費用(仟元/人), dtype: float64
